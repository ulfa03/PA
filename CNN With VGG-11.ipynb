# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import matplotlib.pyplot as plt

# Path direktori
train_dir = r'C:\Users\PC 30 - 316\Documents\PA Ulfa Damayanti\Dataset Daun Cabai\train'
test_dir = r'C:\Users\PC 30 - 316\Documents\PA Ulfa Damayanti\Dataset Daun Cabai\test'  

label_map = {
    'Healthy Leaf': 'Healthy',
    'Yellowish Leaf': 'Yellowish',
    'Leaf Curl': 'Leaf Curl',
    'Spot Leaf': 'Leaf Spot',
    'Whitefly Leaf': 'Whitefly'
}

def count_images_per_class(directory):
    class_counts = {}
    for class_name in os.listdir(directory):
        class_path = os.path.join(directory, class_name)
        if os.path.isdir(class_path):
            num_images = len([
                f for f in os.listdir(class_path)
                if f.lower().endswith(('.jpg', '.png', '.jpeg'))
            ])
            class_counts[class_name] = num_images
    return class_counts

train_counts = count_images_per_class(train_dir)



train_counts_named = {label_map[k]: v for k, v in train_counts.items()}


print("Distribusi Kelas (Train):")
for label, count in train_counts_named.items():
    print(f"  {label}: {count}")

# Plot bar chart
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.bar(train_counts_named.keys(), train_counts_named.values(), color='skyblue')
plt.title("Train Class Distribution")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Distribusi Kelas (Train):
#   Healthy: 1720
#   Leaf Curl: 1729
#   Leaf Spot: 1738
#   Whitefly: 1700
#   Yellowish: 1721

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Path ke direktori
base_dir = r'C:\Users\PC 30 - 316\Documents\PA Ulfa Damayanti\Dataset Daun Cabai'
train_dir = base_dir + r'\train'
val_dir = base_dir + r'\val'
test_dir = base_dir + r'\test'

# Normalisasi gambar (tanpa augmentasi tambahan)
datagen = ImageDataGenerator(rescale=1./255)

# Load training data
train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(48, 48),
    batch_size=32,
    class_mode='categorical',
    shuffle=True
)

# Load validation data
val_generator = datagen.flow_from_directory(
    val_dir,
    target_size=(48, 48),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

# Load test data
test_generator = datagen.flow_from_directory(
    test_dir,
    target_size=(48, 48),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 8608 images belonging to 5 classes.
# Found 1075 images belonging to 5 classes.
# Found 1079 images belonging to 5 classes.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Path ke direktori
base_dir = r'C:\Users\PC 30 - 316\Documents\PA Ulfa Damayanti\Dataset Daun Cabai'
train_dir = base_dir + r'\train'
val_dir = base_dir + r'\val'
test_dir = base_dir + r'\test'

# Normalisasi gambar (tanpa augmentasi tambahan)
datagen = ImageDataGenerator(rescale=1./255)

# Load training data
train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(48, 48),
    batch_size=32,
    class_mode='categorical',
    shuffle=True
)

# Load validation data
val_generator = datagen.flow_from_directory(
    val_dir,
    target_size=(48, 48),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

# Load test data
test_generator = datagen.flow_from_directory(
    test_dir,
    target_size=(48, 48),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 8608 images belonging to 5 classes.
# Found 1075 images belonging to 5 classes.
# Found 1079 images belonging to 5 classes.

# %% [markdown]
# Build Model (VGG-16)

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras import regularizers

# Load VGG16 tanpa top layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(48, 48, 3))

for layer in base_model.layers:
    layer.trainable = False
for layer in base_model.layers[-15:]:
    layer.trainable = True

# Custom classifier dengan Batch Normalization
x = GlobalAveragePooling2D()(base_model.output)
          
x = Dense(128, activation='selu')(x)
x = Dropout(0.5)(x)

# x = Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001))(x)
# x = Dropout(0.5)(x)
output = Dense(train_generator.num_classes, activation='softmax')(x)

# Bangun dan compile model
model = Model(inputs=base_model.input, outputs=output)
model.compile(optimizer=Adam(learning_rate=1e-4, beta_1=0.9, beta_2=0.999), loss='categorical_crossentropy', metrics=['accuracy'])

# Cek arsitektur model
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 48, 48, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 48, 48, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 48, 48, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 24, 24, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 24, 24, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 24, 24, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 12, 12, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 12, 12, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 12, 12, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 12, 12, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 6, 6, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 6, 6, 512)           │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 6, 6, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 6, 6, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 3, 3, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 3, 3, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 3, 3, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 3, 3, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 1, 1, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 512)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          65,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 5)                   │             645 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,780,997 (56.39 MB)
#  Trainable params: 14,742,277 (56.24 MB)
#  Non-trainable params: 38,720 (151.25 KB)

# %% [markdown]
# Training Model

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

checkpoint = ModelCheckpoint(
    'best_model.keras',
    monitor='val_loss',
    save_best_only=True,
    mode='min',
    verbose=1
)

# ReduceLROnPlateau: mengurangi learning rate saat val_loss stagnan
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=2,
    min_lr=1e-6,
    verbose=1
)

# EarlyStopping: hentikan training jika val_loss tidak membaik
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=4,             # berhenti jika tidak ada perbaikan dalam 3 epoch
    restore_best_weights=True,  # kembali ke model dengan val_loss terbaik
    verbose=1
)

# Gabungkan semua callback
callbacks = [checkpoint, reduce_lr, early_stop]

# Training model
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=50,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# C:\Users\PC 30 - 316\AppData\Roaming\Python\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step - accuracy: 0.5239 - loss: 1.1796
# Epoch 1: val_loss improved from inf to 0.51598, saving model to best_model.keras
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 125s 455ms/step - accuracy: 0.5243 - loss: 1.1785 - val_accuracy: 0.8130 - val_loss: 0.5160 - learning_rate: 1.0000e-04
# Epoch 2/50
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step - accuracy: 0.8240 - loss: 0.4801
# Epoch 2: val_loss improved from 0.51598 to 0.34484, saving model to best_model.keras
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 123s 458ms/step - accuracy: 0.8240 - loss: 0.4800 - val_accuracy: 0.8791 - val_loss: 0.3448 - learning_rate: 1.0000e-04
# Epoch 3/50
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step - accuracy: 0.9060 - loss: 0.2613
# Epoch 3: val_loss improved from 0.34484 to 0.18677, saving model to best_model.keras
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 123s 456ms/step - accuracy: 0.9060 - loss: 0.2613 - val_accuracy: 0.9405 - val_loss: 0.1868 - learning_rate: 1.0000e-04
# Epoch 4/50
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - accuracy: 0.9443 - loss: 0.1579
# Epoch 4: val_loss improved from 0.18677 to 0.17935, saving model to best_model.keras
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 122s 453ms/step - accuracy: 0.9443 - loss: 0.1579 - val_accuracy: 0.9451 - val_loss: 0.1794 - learning_rate: 1.0000e-04
# Epoch 5/50
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step - accuracy: 0.9499 - loss: 0.1456
# Epoch 5: val_loss improved from 0.17935 to 0.16560, saving model to best_model.keras
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 123s 458ms/step - accuracy: 0.9499 - loss: 0.1456 - val_accuracy: 0.9433 - val_loss: 0.1656 - learning_rate: 1.0000e-04
# Epoch 6/50
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step - accuracy: 0.9785 - loss: 0.0685
# Epoch 6: val_loss improved from 0.16560 to 0.12098, saving model to best_model.keras
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 121s 451ms/step - accuracy: 0.9785 - loss: 0.0685 - val_accuracy: 0.9665 - val_loss: 0.1210 - learning_rate: 1.0000e-04
# Epoch 7/50
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step - accuracy: 0.9834 - loss: 0.0532
# Epoch 7: val_loss did not improve from 0.12098
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 122s 453ms/step - accuracy: 0.9834 - loss: 0.0532 - val_accuracy: 0.9544 - val_loss: 0.1584 - learning_rate: 1.0000e-04
# Epoch 8/50
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step - accuracy: 0.9891 - loss: 0.0369
# Epoch 8: val_loss improved from 0.12098 to 0.11799, saving model to best_model.keras
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 123s 458ms/step - accuracy: 0.9891 - loss: 0.0370 - val_accuracy: 0.9702 - val_loss: 0.1180 - learning_rate: 1.0000e-04
# Epoch 9/50
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - accuracy: 0.9848 - loss: 0.0500
# Epoch 9: val_loss did not improve from 0.11799
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 120s 446ms/step - accuracy: 0.9848 - loss: 0.0501 - val_accuracy: 0.9581 - val_loss: 0.1468 - learning_rate: 1.0000e-04
# Epoch 10/50
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - accuracy: 0.9872 - loss: 0.0537
# Epoch 10: val_loss did not improve from 0.11799
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 120s 446ms/step - accuracy: 0.9872 - loss: 0.0537 - val_accuracy: 0.9544 - val_loss: 0.1547 - learning_rate: 1.0000e-04
# Epoch 11/50
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - accuracy: 0.9965 - loss: 0.0173
# Epoch 11: val_loss improved from 0.11799 to 0.10218, saving model to best_model.keras
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 121s 451ms/step - accuracy: 0.9965 - loss: 0.0172 - val_accuracy: 0.9749 - val_loss: 0.1022 - learning_rate: 5.0000e-05
# Epoch 12/50
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 0s 439ms/step - accuracy: 0.9967 - loss: 0.0105
# Epoch 12: val_loss did not improve from 0.10218
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 122s 455ms/step - accuracy: 0.9967 - loss: 0.0105 - val_accuracy: 0.9721 - val_loss: 0.1229 - learning_rate: 5.0000e-05
# Epoch 13/50
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step - accuracy: 0.9973 - loss: 0.0088
# Epoch 13: val_loss improved from 0.10218 to 0.06056, saving model to best_model.keras
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 123s 458ms/step - accuracy: 0.9973 - loss: 0.0088 - val_accuracy: 0.9814 - val_loss: 0.0606 - learning_rate: 5.0000e-05
# Epoch 14/50
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - accuracy: 0.9980 - loss: 0.0055
# Epoch 14: val_loss improved from 0.06056 to 0.05647, saving model to best_model.keras
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 121s 451ms/step - accuracy: 0.9980 - loss: 0.0055 - val_accuracy: 0.9823 - val_loss: 0.0565 - learning_rate: 5.0000e-05
# Epoch 15/50
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - accuracy: 0.9995 - loss: 0.0024
# Epoch 15: val_loss did not improve from 0.05647
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 122s 455ms/step - accuracy: 0.9995 - loss: 0.0024 - val_accuracy: 0.9814 - val_loss: 0.0851 - learning_rate: 5.0000e-05
# Epoch 16/50
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - accuracy: 0.9979 - loss: 0.0049
# Epoch 16: val_loss did not improve from 0.05647
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 122s 455ms/step - accuracy: 0.9979 - loss: 0.0049 - val_accuracy: 0.9860 - val_loss: 0.0668 - learning_rate: 5.0000e-05
# Epoch 17/50
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - accuracy: 0.9995 - loss: 0.0020
# Epoch 17: val_loss improved from 0.05647 to 0.05224, saving model to best_model.keras
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 124s 461ms/step - accuracy: 0.9995 - loss: 0.0020 - val_accuracy: 0.9870 - val_loss: 0.0522 - learning_rate: 2.5000e-05
# Epoch 18/50
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step - accuracy: 0.9993 - loss: 0.0024
# Epoch 18: val_loss improved from 0.05224 to 0.05000, saving model to best_model.keras
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 122s 452ms/step - accuracy: 0.9993 - loss: 0.0024 - val_accuracy: 0.9833 - val_loss: 0.0500 - learning_rate: 2.5000e-05
# Epoch 19/50
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - accuracy: 0.9993 - loss: 0.0019
# Epoch 19: val_loss did not improve from 0.05000
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 122s 455ms/step - accuracy: 0.9993 - loss: 0.0019 - val_accuracy: 0.9879 - val_loss: 0.0538 - learning_rate: 2.5000e-05
# Epoch 20/50
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - accuracy: 0.9996 - loss: 0.0018
# Epoch 20: val_loss did not improve from 0.05000
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 123s 455ms/step - accuracy: 0.9996 - loss: 0.0018 - val_accuracy: 0.9888 - val_loss: 0.0515 - learning_rate: 2.5000e-05
# Epoch 21/50
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - accuracy: 0.9996 - loss: 0.0015
# Epoch 21: val_loss improved from 0.05000 to 0.04961, saving model to best_model.keras
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 124s 461ms/step - accuracy: 0.9996 - loss: 0.0015 - val_accuracy: 0.9907 - val_loss: 0.0496 - learning_rate: 1.2500e-05
# Epoch 22/50
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - accuracy: 0.9995 - loss: 0.0013
# Epoch 22: val_loss did not improve from 0.04961
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 122s 454ms/step - accuracy: 0.9995 - loss: 0.0013 - val_accuracy: 0.9888 - val_loss: 0.0497 - learning_rate: 1.2500e-05
# Epoch 23/50
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - accuracy: 0.9998 - loss: 7.2910e-04
# Epoch 23: val_loss did not improve from 0.04961
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 123s 457ms/step - accuracy: 0.9998 - loss: 7.3061e-04 - val_accuracy: 0.9879 - val_loss: 0.0527 - learning_rate: 1.2500e-05
# Epoch 24/50
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - accuracy: 0.9995 - loss: 0.0012
# Epoch 24: val_loss improved from 0.04961 to 0.04835, saving model to best_model.keras
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 124s 461ms/step - accuracy: 0.9995 - loss: 0.0012 - val_accuracy: 0.9898 - val_loss: 0.0484 - learning_rate: 6.2500e-06
# Epoch 25/50
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - accuracy: 0.9990 - loss: 0.0023
# Epoch 25: val_loss did not improve from 0.04835
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 123s 458ms/step - accuracy: 0.9990 - loss: 0.0023 - val_accuracy: 0.9888 - val_loss: 0.0491 - learning_rate: 6.2500e-06
# Epoch 26/50
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - accuracy: 0.9994 - loss: 7.6639e-04
# Epoch 26: val_loss did not improve from 0.04835
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 124s 460ms/step - accuracy: 0.9994 - loss: 7.6684e-04 - val_accuracy: 0.9888 - val_loss: 0.0514 - learning_rate: 6.2500e-06
# Epoch 27/50
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - accuracy: 0.9999 - loss: 3.7433e-04
# Epoch 27: val_loss did not improve from 0.04835
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 123s 459ms/step - accuracy: 0.9999 - loss: 3.7536e-04 - val_accuracy: 0.9888 - val_loss: 0.0501 - learning_rate: 3.1250e-06
# Epoch 28/50
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - accuracy: 0.9999 - loss: 4.1792e-04
# Epoch 28: val_loss improved from 0.04835 to 0.04830, saving model to best_model.keras
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 125s 464ms/step - accuracy: 0.9999 - loss: 4.1911e-04 - val_accuracy: 0.9898 - val_loss: 0.0483 - learning_rate: 3.1250e-06
# Epoch 29/50
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - accuracy: 0.9996 - loss: 8.9255e-04
# Epoch 29: val_loss did not improve from 0.04830
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 123s 457ms/step - accuracy: 0.9996 - loss: 8.9201e-04 - val_accuracy: 0.9888 - val_loss: 0.0501 - learning_rate: 1.5625e-06
# Epoch 30/50
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - accuracy: 0.9999 - loss: 6.7278e-04
# Epoch 30: val_loss did not improve from 0.04830
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1e-06.
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 123s 458ms/step - accuracy: 0.9999 - loss: 6.7243e-04 - val_accuracy: 0.9888 - val_loss: 0.0507 - learning_rate: 1.5625e-06
# Epoch 31/50
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - accuracy: 1.0000 - loss: 4.0914e-04
# Epoch 31: val_loss did not improve from 0.04830
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 123s 457ms/step - accuracy: 1.0000 - loss: 4.0943e-04 - val_accuracy: 0.9888 - val_loss: 0.0511 - learning_rate: 1.0000e-06
# Epoch 32/50
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - accuracy: 0.9999 - loss: 6.8601e-04
# Epoch 32: val_loss did not improve from 0.04830
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 123s 458ms/step - accuracy: 0.9999 - loss: 6.8585e-04 - val_accuracy: 0.9888 - val_loss: 0.0515 - learning_rate: 1.0000e-06
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 28.

# %%
loss, accuracy = model.evaluate(test_generator)
print(f"Test accuracy: {accuracy:.4f}")

loss, acc = model.evaluate(test_generator)
print(f"Akurasi akhir di data test: {acc:.2f}")
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.9795 - loss: 0.1307
# Test accuracy: 0.9861
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - accuracy: 0.9795 - loss: 0.1307
# Akurasi akhir di data test: 0.99

# %% [markdown]
# Plot Training History

# %%
import matplotlib.pyplot as plt

# Plot akurasi
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy', marker='o')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', marker='o')
plt.title('Training vs Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss', marker='o')
plt.plot(history.history['val_loss'], label='Validation Loss', marker='o')
plt.title('Training vs Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# Confusion Matrix and Classification Report (Validation)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

Y_pred = model.predict(val_generator)
y_pred = np.argmax(Y_pred, axis=1)


y_true = val_generator.classes


cm = confusion_matrix(y_true, y_pred)

class_names = list(val_generator.class_indices.keys())

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

print("\nClassification Report:\n")
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step
# Classification Report:
#
#                 precision    recall  f1-score   support
#
#   Healthy Leaf       0.98      0.98      0.98       215
#      Leaf Curl       1.00      0.98      0.99       216
#      Spot Leaf       0.98      0.99      0.99       217
#  Whitefly Leaf       1.00      1.00      1.00       212
# Yellowish Leaf       1.00      1.00      1.00       215
#
#       accuracy                           0.99      1075
#      macro avg       0.99      0.99      0.99      1075
#   weighted avg       0.99      0.99      0.99      1075

# %% [markdown]
# Confusion Matrix and Classification Report (Testing)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

Y_pred = model.predict(test_generator)
y_pred = np.argmax(Y_pred, axis=1)
y_true = test_generator.classes

class_names = list(test_generator.class_indices.keys())

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.tight_layout()
plt.show()


print("\nClassification Report:\n")
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step
# Classification Report:
#
#                 precision    recall  f1-score   support
#
#   Healthy Leaf       0.97      0.97      0.97       215
#      Leaf Curl       0.99      0.99      0.99       217
#      Spot Leaf       0.98      0.98      0.98       218
#  Whitefly Leaf       1.00      1.00      1.00       214
# Yellowish Leaf       1.00      0.99      0.99       215
#
#       accuracy                           0.99      1079
#      macro avg       0.99      0.99      0.99      1079
#   weighted avg       0.99      0.99      0.99      1079

# %% [markdown]
# Save Model (TFlite)

# %%
import tensorflow as tf

model = tf.keras.models.load_model("best_model.keras")
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

with open("modelvgg16.tflite", "wb") as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\PC30-3~1\AppData\Local\Temp\tmpz32ym2f2\assets
# INFO:tensorflow:Assets written to: C:\Users\PC30-3~1\AppData\Local\Temp\tmpz32ym2f2\assets
